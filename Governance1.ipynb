# %% [markdown]
# <a href="https://colab.research.google.com/github/svanderzeil/projects/blob/master/Governance1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a supervised machine learning experiment using company data to analyze whether knowing a company's particular governance arrangements provides a strong indication of the sector.
#
# Data used in this analysis is the Russell 3000 from the United States

# %%
# Use seaborn for pairplot
# !pip install seaborn
#Use google spread sheet link
# !pip install --upgrade -q gspread

# %%
# Import all the required programs - pathlib for matpol


import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 1.13.1

# %%
#Import governance data from Google spreadsheet 
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('Governance_data').sheet1

col_names = worksheet.row_values(1)
print(col_names)

# Convert to a DataFrame and render.
data = worksheet.get_all_values()
pd.DataFrame.from_records(data)
# Out:
# ['Sector', 'Overboarded Exec Directors', 'Oversized Board', 'Gender Diversity', 'Overboarded Audit Committee Members', 'Risk Management Expertise', 'Pay Performance Links', 'Executives on Audit Committee', 'Audit Committee Independence', 'Audit Committee Fin Expert', 'Executives on Audit Board', 'Comp Committee Independence', 'No Comp Committee / Execs on Board', 'Executives on Comp Committee', 'Overboarded Non-Exec Directors', 'Comp Committee Alignment', 'Combined CEO/Chair', 'No Independent Directors', 'Executives on Board', 'CEOs on Board', 'Independent Lead Director', 'Independent Chair', 'Executive Chair']
#                                           0                           1   \
# 0                                     Sector  Overboarded Exec Directors
# 1         Cyclical Consumer Goods / Services                     Flagged
# 2                                 Financials                 Not Flagged
# 3                                 Technology                 Not Flagged
# ...

# %% [markdown]
# The governance data is set out by company with a range of governance attributes such as board election, proxy voting, gender diversity etc etc. We want to import the data, make sure it is working and turn the indicators (flagged, not flagged) into numeric (1,0)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-bb2af57e4ac1> in <module>()
# ----> 1 data.DataFrame()
#       2 data.replace('Flagged', 1)
#       3
#
# AttributeError: 'list' object has no attribute 'DataFrame'
